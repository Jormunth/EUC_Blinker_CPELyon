# %%
from datetime import datetime
import pandas as pd

# Path to the CSV file
df = pd.read_csv('ble_mpu6050_logs.csv')
df
# Out:
#                      Timestamp  Accel_X (g)  Accel_Y (g)  Accel_Z (g)  \
# 0   2025-01-07T14:15:00.788531    1030.2734     -43.7012      -6.3477
# 1   2025-01-07T14:15:01.283549    1029.0527     -41.0156      11.9629
# 2   2025-01-07T14:15:01.823641    1028.5645     -40.2832       7.8125
# 3   2025-01-07T14:15:02.318088    1033.6914     -41.0156      -4.1504
# 4   2025-01-07T14:15:02.813642    1029.0527     -40.5273      -3.4180
# 5   2025-01-07T14:15:03.307721    1027.8320     -45.8984      24.1699
# 6   2025-01-07T14:15:03.803125    1020.5078     -43.2129      14.6484
# 7   2025-01-07T14:15:04.298081    1029.0527     -48.0957      11.2305
# 8   2025-01-07T14:15:04.838310    1026.6113     -38.8184       8.0566
# 9   2025-01-07T14:15:05.333132    1030.0293     -46.8750      10.0098
# 10  2025-01-07T14:15:05.827697    1029.5410     -41.5039      -0.2441
# 11  2025-01-07T14:15:06.322607    1030.5176     -41.7480       0.7324
# ...

# %%
# %matplotlib qt
df.plot()
# Out:
# <Axes: >
