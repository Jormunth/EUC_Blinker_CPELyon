# %%
from datetime import datetime
import pandas as pd

# Path to the CSV file
df = pd.read_csv('ble_mpu6050_logs.csv')
df
# Out:
#                      Timestamp  Accel_X (g)  Accel_Y (g)  Accel_Z (g)  \
# 0   2025-01-06T16:47:41.550824    1017.8223    -117.9199      -4.6387
# 1   2025-01-06T16:47:42.090677    1027.3438    -110.8398      -7.0801
# 2   2025-01-06T16:47:42.585672    1024.1699    -114.5020       8.5449
# 3   2025-01-06T16:47:43.080862    1020.2637    -112.7930      -2.6855
# 4   2025-01-06T16:47:43.575955    1017.8223    -113.5254      -3.9062
# 5   2025-01-06T16:47:44.071071    1014.4043    -108.1543     -10.7422
# 6   2025-01-06T16:47:44.565400    1025.1465    -113.2813     -13.9160
# 7   2025-01-06T16:47:45.105743    1025.6348    -117.4316     -10.0098
# 8   2025-01-06T16:47:45.600387    1017.5781    -107.9102      -8.7891
# 9   2025-01-06T16:47:46.095997    1025.1465    -118.4082      -7.5684
# 10  2025-01-06T16:47:46.590643    1025.6348    -115.9668      -0.7324
# 11  2025-01-06T16:47:47.085475    1024.1699    -114.5020       2.9297
# ...

# %%
df["test"] = df["Accel_X (g)"]-df["Accel_Y (g)"]
df.plot(x="Timestamp", y="test")
# Out:
# <Axes: xlabel='Timestamp'>
