# %%
df = pd.read_csv(file_path, encoding='utf-16',skiprows=1)
df
# Out:
#      time[us]  acc_x[mg]  acc_y[mg]  acc_z[mg]  gyro_x[mdps]  gyro_y[mdps]  \
# 0     3873736       1048         67       -130         -2038         -1557
# 1     3892769       1057         72       -128         -1778         -1351
# 2     3911762       1054         70       -133         -1679          -679
# 3     3930765       1052         73       -109         -1977          -809
# 4     3949770       1046         74       -112         -2511          -664
# ..        ...        ...        ...        ...           ...           ...
# 419  11834765       1049        -14        -93         -2099         -1778
# 420  11853762       1048        -13        -93         -2007         -1740
# 421  11872765       1049        -12       -104         -2099         -1458
# 422  11891762       1051          1        -93         -1763         -1435
# 423  11910765       1059          0        -99         -1854          -992
#
#      gyro_z[mdps]
# 0             717
# 1             854
# ...

# %%
import matplotlib.pyplot as plt

# Convert time from microseconds to seconds
df['time[s]'] = df['time[us]'] / 1e6

# Plot Acceleration Data (acc_x, acc_y, acc_z)
plt.figure(figsize=(12, 6))

# First subplot: Acceleration data
plt.subplot(1, 2, 1)
plt.plot(df['time[s]'], df['acc_x[mg]'], label='Acc X')
plt.plot(df['time[s]'], df['acc_y[mg]'], label='Acc Y')
plt.plot(df['time[s]'], df['acc_z[mg]'], label='Acc Z')
plt.title('Accelerometer Data')
plt.xlabel('Time [s]')
plt.ylabel('Acceleration [mg]')
plt.legend()
plt.grid(True)

# Second subplot: Gyroscope data
plt.subplot(1, 2, 2)
plt.plot(df['time[s]'], df['gyro_x[mdps]'], label='Gyro X')
plt.plot(df['time[s]'], df['gyro_y[mdps]'], label='Gyro Y')
plt.plot(df['time[s]'], df['gyro_z[mdps]'], label='Gyro Z')
plt.title('Gyroscope Data')
plt.xlabel('Time [s]')
plt.ylabel('Gyroscope [mdps]')
plt.legend()
plt.grid(True)

# Adjust layout and show plots
plt.tight_layout()
plt.show()
